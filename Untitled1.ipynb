# %%
from manim import *

# %%
# %%manim -qm OpeningManim
# class OpeningManim(Scene):
#     def construct(self):
#         basel = MathTex(r"ROI = \frac{Valor Corrente do Investimento - Custo do Investimento}{Custo do Investimento}")
#         VGroup(basel).arrange(DOWN)
#         self.play(
#             FadeIn(basel, shift=DOWN),
#         )
# Out:
# [10/20/23 11:15:55] INFO     Animation 0 : Partial movie file written in                   ]8;id=645117;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=71529;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/home/m/learncomplex/media/videos/learncomplex/720p30/partia
#                              l_movie_files/OpeningManim/274514146_3604688251_223132457.mp4
#                              '
#                     INFO     Combining to Movie file.                                      ]8;id=118156;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=493405;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=489551;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=643201;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/home/m/learncomplex/media/videos/learncomplex/720p30/Openin
#                              gManim.mp4'
#                     INFO     Rendered OpeningManim                                                     ]8;id=360800;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=756999;file:///home/m/complex/lib/python3.11/site-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 1 animations
# <video src="media/jupyter/OpeningManim@2023-10-20@11-15-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation
import matplotlib
from tqdm.notebook import tqdm
import cmasher
from scipy.interpolate import interp1d
import seaborn as sns
import time

def gauss(x, mu, sigma):
    return np.exp(-(x-mu)**2 / (sigma)**2)

amplitude_cmap = cmasher.get_sub_cmap(cmasher.ember, 0.5, 0.8)
amplitude =  gauss(time, 2,1) + gauss(time,4,0.5)

fig, ax = setup_time_axes()
ax.grid(False)
lc = plot_LineCollection_on_axis(ax, time, amplitude, colors = amplitude_cmap(amplitude[:-1]), linewidths=7)

fill = ax.fill_between(time, 0, amplitude, color="white")

anim = animate_line_collections([lc],fig,fills=[],frame_downsampling=FRAME_DOWNSAMPLING)
anim.save("renders/4) Animating power modulation – curve.mp4")

ax.grid(False)
anim = animate_line_collections([lc],fig,[fill],only_fills=True,frame_downsampling=FRAME_DOWNSAMPLING)
anim.save("renders/4) Animating power modulation – fill.mp4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 15
#      12     return np.exp(-(x-mu)**2 / (sigma)**2)
#      14 amplitude_cmap = cmasher.get_sub_cmap(cmasher.ember, 0.5, 0.8)
# ---> 15 amplitude =  gauss(time, 2,1) + gauss(time,4,0.5)
#      17 fig, ax = setup_time_axes()
#      18 ax.grid(False)
#
# Cell In[34], line 12, in gauss(x, mu, sigma)
#      11 def gauss(x, mu, sigma):
# ---> 12     return np.exp(-(x-mu)**2 / (sigma)**2)
#
# TypeError: unsupported operand type(s) for -: 'module' and 'int'

# %%
# !pip install seaborn cmasher
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting cmasher
#   Downloading cmasher-1.6.3-py3-none-any.whl (367 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.1/367.1 kB 5.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/m/complex/lib/python3.11/site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in /home/m/complex/lib/python3.11/site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /home/m/complex/lib/python3.11/site-packages (from seaborn) (3.8.0)
# Collecting colorspacious>=1.1.0 (from cmasher)
#   Downloading colorspacious-1.1.2-py2.py3-none-any.whl (37 kB)
# Collecting e13tools>=0.9.4 (from cmasher)
#   Downloading e13tools-0.9.6-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/m/complex/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/m/complex/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/m/complex/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/m/complex/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 6.6 MB/s eta 0:00:0011.9 MB/s eta 0:00:01
# Installing collected packages: colorspacious, seaborn, e13tools, cmasher
# Successfully installed cmasher-1.6.3 colorspacious-1.1.2 e13tools-0.9.6 seaborn-0.13.0

# %%
import cmasher as cmr

# Import packages for plotting
import matplotlib.pyplot as plt
import numpy as np

# Access rainforest colormap through CMasher or MPL
cmap = cmr.rainforest                   # CMasher
cmap = plt.get_cmap('cmr.rainforest')   # MPL

# Generate some data to plot
x = np.random.rand(100)
y = np.random.rand(100)
z = x**2+y**2

# Make scatter plot of data with colormap
plt.scatter(x, y, c=z, cmap=cmap, s=300)
plt.show()

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

# read data from a text file. One number per line
arch = "nums2.txt"
data = []
for item in open(arch,'r'):
    item = item.strip()
    if item != '':
        try:
            data.append(float(item))
        except ValueError:
            pass

# best fit of data
(mu, sigma) = norm.fit(data)

# the histogram of the data
n, bins, patches = plt.hist(data, 20, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = norm.pdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)

#plot
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=%.3f,\ \sigma=%.3f$' %(mu, sigma))
plt.grid(True)
plt.show()
plt.savefig('temp.png')

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/m/learncomplex'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

def normal(mean, std, color="black"):
    x = np.linspace(mean-3*std, mean+3*std, 200)
    p = stats.norm.pdf(x, mean, std)
    z = plt.plot(x, p, color, linewidth=2)
data = np.array(data)
ax = sns.histplot(x=data, stat="density")
data.mean()
ax.set_title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=%.3f,\ \sigma=%.3f$' %(data.mean(), data.std()))
normal(data.mean(), data.std())
